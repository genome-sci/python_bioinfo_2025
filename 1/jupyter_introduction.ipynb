# %% [markdown]
# # Jupyter notebookな基本的な使い方

# %% [markdown]
# ## コマンドモードと編集モード

# %% [markdown]
# * コマンドモード
#   セルの移動、挿入、削除などの操作を行う
#   セルの外枠が青になっている状態
# * 編集モード
#   セルが選択された状態でEnterを押すと編集モードに入る
#   shift + Enter を押すと、セルの内容が実行される
#   ESCを押すか、セルの外側をクリックするとコマンドモードに入る

# %% [markdown]
# ## セルを選択した状態で shift + Enter を押すと実行されます

# %%
print("Hello")

# %%
# 最後に評価された式の返り値が、自動的に出力されます。
a = list(range(10))
sorted(a, reverse=True)

# %% [markdown]
# ## ヘルプの参照

# %% [markdown]
# * キーボードショートカットの表示
# Help --> Keyboard Shortcuts

# %% [markdown]
# * 関数、メソッドのヘルプ
# 後に?をつける

# %%
sorted?

# %%
# BiopythonパッケージからからSeqIOモジュールをインポート
from Bio import SeqIO

# %%
SeqIO.parse?

# %% [markdown]
# ## セルの基本操作（絶対に覚えておいた方が良いショートカット）

# %% [markdown]
# * 上にセルを挿入
#   コマンドモードで a を押す(above)
# * 下にセルを挿入
#   コマンドモードで b を押す(below)
# * セルの挿入
#   コマンドモードで d を続けて二回押す。(delete)
# * セルのカット・コピー・ペースト
#   コマンドモードで それぞれx、c、vを押す
# * セル内容の実行
#   shift + Enter (コマンドモード、編集モードどちらでも）

# %% [markdown]
# ## セルの種類

# %% [markdown]
# * マークダウンセル
#   このセルは __マークダウン__ で記載されています。
#   マークダウンを使うと様々な _書式_ を指定することができます。
#   詳しくは[こちらのリンク先](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html)を参照。
#   コードを表示させることもできます。
# ```
# def func(a):
#     return str(a).upper()
# ```
# セルをマークダウンに変更するには、コマンドモードで m を押すか、画面上部のメニューバーで変更します。

# %% [markdown]
# * コードセル

# %%
10 + 10

# %%
print("このセルは実行可能なコードを含みます。")
message = "新規挿入されたセルはデフォルトでコードセルになっています。"
message += "\nコマンドモードで y を押すとコードセルに変更できます。"
print(message)

# %% [markdown]
# # 便利な使い方

# %% [markdown]
# ## タブによる補完

# %% [markdown]
# 入力の途中で TAB を押すと、変数名・関数名・ファイル名などの補完ができます。

# %%
import math

# %%
# math. まで打って TAB を押すと候補が表示されることを確認してください
math.co

# %%
dir?

# %%
# dir 関数を使用すると、どのような機能・属性が含まれているかわかります。
dir(math)

# %%
# 文字列オブジェクトが持つメソッドなどを表示します。
a = "Hello"
dir(a)

# %%
a.capitalize()

# %% [markdown]
# ## 一部のシェルコマンドはそのまま使用可能

# %%
ls

# %%
pwd

# %% [markdown]
# ## ! をつけるとシェルコマンドの内容をリストとして取得できる

# %%
ret = !cat README.md | head -5

# %%
for line in ret:
    print(line)

# %% [markdown]
# ## マジックコマンド

# %% [markdown]
# ### 先頭に % をつけられたマジックコマンドは一行を対象にする

# %%
# 実行時間を測定
# %time range(1000000)

# %%
# 環境変数を表示
# %env PATH

# %%
# 返り値を取得することも可能
path = %env PATH
print(path.split(":")[0])

# %%
# 変数一覧 %who および　詳細情報 %whos
# %whos

# %%
# マジックコマンドについてのヘルプを表示
# %quickref

# %% [markdown]
# ### 先頭に %% をつけられたマジックコマンドはセル全体を対象にする

# %% [markdown]
# * %%bash
# セル全体をシェルスクリプトとして実行

# %%
# %%bash
# for i in `seq 1 10`
# do
#   echo $i
# done

# %% [markdown]
# * %%time or %%timeit
# 実行時間を計測

# %%
# %%time
sum = 0
for x in range(100000):
    sum += x
print(sum)

# %% [markdown]
# # AIによるコーディング支援

# %% [markdown]
# ## Notebook Intelligence

# %% [markdown]
# Notebook Intelligence は Jupyter Notebook/Lab で Github Copilot などのAIによるコーディング支援を行うためのプラグインです。
# 以下のコマンドでインストールした後、Jupyterを起動しなおすと有効になります。
# ```
# pip install notebook-intelligence
# ```

# %% [markdown]
# デフォルトでは Github Copilot を使用するようになっています。Github Copilot は有償ですが、学生・教職員・オープンソース開発者は無料・割引のプランが用意されています。[GitHub Education](https://docs.github.com/ja/education) を参照してください。

# %% [markdown]
# 起動すると左のパネルにログインボタンが表示されますので、指示に従ってログインしてください。

# %% [markdown]
# <img src="img/1.png" alt="figure1" width="75%">

# %% [markdown]
# 途中で認証用のコードが表示されるので指定されたURLにアクセスし、コードを入力します。

# %% [markdown]
# <img src="img/2.png" alt="figure1" width="50%">

# %% [markdown]
# ログインが完了すると、左のパネルでAIに質問したりコードの生成を依頼したりできます。

# %% [markdown]
# <img src="img/3.png" alt="figure1" width="75%">

# %% [markdown]
# セル内にコードを生成するためのアイコンが追加されます。

# %% [markdown]
# <img src="img/4.png" alt="figure1" width="75%">

# %% [markdown]
# ## VScode を使う方法

# %% [markdown]
# notebook ファイル (.ipynb) を直接開いて編集することができます。
# VScode に Jupyter 拡張機能をインストールする必要があります。

# %% [markdown]
# <img src="img/5.png" alt="figure1" width="75%">a

# %% [markdown]
# ## VScode の Python Interactive Window を利用する

# %% [markdown]
# Python スクリプトファイル (.py) に`# %%`と書くことで、セルのようにインタラクティブに実行できます。
# 参考) [Python Interactive Window](https://code.visualstudio.com/docs/python/jupyter-support-py)

# %% [markdown]
# <img src="img/6.png" alt="figure1" width="75%">
